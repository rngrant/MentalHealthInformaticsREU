# %% [markdown]
# # Correlation Analysis
#
# In this notebook we will attempt to analyze the correlations between different clusters in the posts.
#
# We first load all necesary libraries

# %%
#Import graphing utilities
# %matplotlib inline
import matplotlib.pyplot as plt

# Import useful mathematical libraries
import numpy as np
import pandas as pd

# Import useful Machine learning libraries
import gensim
from sklearn.cluster import KMeans

# Import utility files
from utils import save_object, load_object, make_post_clusters, make_clustering_objects

from orangecontrib.associate.fpgrowth import *
# Out:
# //anaconda/lib/python3.5/site-packages/pandas/core/computation/__init__.py:18: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
# Set the model we are going to be analyzing
model_name = "ADHD1"

# %% [markdown]
# ### Make Correlation Matrix

# %%
# Initialize a word clustering to use
num_word_clusters = 100
# Initialize the threshold to count a correlation
correlation_threshold = 0.65

# %%
df = load_object('objects/', model_name + '-df')

# Load Our Saved matricies
PostsByWords = load_object('matricies/', model_name + "-PostsByWords")
WordsByFeatures = load_object('matricies/', model_name + "-WordsByFeatures")

# Generate the posts by Features matrix through matrix multiplication
PostsByFeatures = PostsByWords.dot(WordsByFeatures)
PostsByFeatures = np.matrix(PostsByFeatures)
model = gensim.models.Word2Vec.load('models/' + model_name + '.model')

vocab_list = sorted(list(model.wv.vocab))

kmeans =  load_object('clusters/', model_name + '-words-cluster_model-' + str(num_word_clusters))

clusters = make_clustering_objects(model, kmeans, vocab_list, WordsByFeatures)

clusterWords = list(map(lambda x: list(map(lambda y: y[0] , x["word_list"])), clusters))

from sklearn.feature_extraction.text import CountVectorizer
countvec = CountVectorizer(vocabulary = vocab_list, analyzer = (lambda lst:list(map((lambda s: s), lst))), min_df = 0)

# Make Clusters By Words Matrix
ClustersByWords = countvec.fit_transform(clusterWords)

# take the transpose of Clusters
WordsByCluster = ClustersByWords.transpose()

# Multiply Posts by Words by Words By cluster to get Posts By cluster
PostsByClusters = PostsByWords.dot(WordsByCluster)

# %%
X = np.array(PostsByClusters.todense())

# %%
cluster_df = pd.DataFrame(data = X)

# %%
correlations = cluster_df.corr().values

# %%
# Sort all the words in the words list
for cluster in clusters:
    cluster["word_list"].sort(key = lambda x:x[1], reverse = True)

# %%
correlations_list = []
for i in range(len(correlations)):
    for j in range(i+1,len(correlations[0])):
        corr_val = correlations[i][j]
        if corr_val > correlation_threshold:
            correlations_list.append([i,j,corr_val,clusters[i]["word_list"][:5],clusters[j]["word_list"][:5]])

# %%
len(correlations_list)
# Out:
# 129

# %%
correlations_list
# Out:
# [[3,
#   6,
#   0.79548957519921693,
#   [('i', 535156),
#    ('and', 310199),
#    ('a', 242372),
#    ('it', 148143),
#    ('that', 128064)],
#   [('do', 61744),
#    ('make', 12200),
#    ('find', 11436),
#    ('keep', 7870),
#    ('able', 5035)]],
#  [3,
#   16,
#   0.68914223546037157,
#   [('i', 535156),
#    ('and', 310199),
#    ('a', 242372),
#    ('it', 148143),
#    ('that', 128064)],
#   [('been', 24612),
#    ('since', 11348),
#    ('ive_been', 10559),
#    ('years', 8671),
#    ('year', 5689)]],
#  [3,
#   18,
#   0.79678357756738349,
#   [('i', 535156),
#    ('and', 310199),
#    ('a', 242372),
#    ('it', 148143),
#    ('that', 128064)],
#   [('some', 24841),
#    ('other', 13101),
#    ('lot', 12478),
#    ('these', 9147),
#    ('most', 8148)]],
#  [3,
#   31,
#   0.8794464230583906,
#   [('i', 535156),
#    ('and', 310199),
#    ('a', 242372),
#    ('it', 148143),
#    ('that', 128064)],
#   [('my', 203658),
#    ('was', 80310),
#    ('had', 32794),
#    ('ive', 22719),
#    ('after', 19616)]],
#  [3,
#   36,
#   0.79445868548214038,
#   [('i', 535156),
#    ('and', 310199),
#    ('a', 242372),
#    ('it', 148143),
#    ('that', 128064)],
#   [('one', 22863),
#    ('long', 8918),
#    ('days', 6881),
#    ('every', 6517),
#    ('two', 6037)]],
#  [3,
#   53,
#   0.79432536487118299,
#   [('i', 535156),
#    ('and', 310199),
#    ('a', 242372),
#    ('it', 148143),
#    ('that', 128064)],
#   [('life', 18478),
#    ('myself', 15524),
#    ('getting', 12259),
#    ('having', 10137),
#    ('through', 9882)]],
#  [3,
#   61,
#   0.93034419608408703,
#   [('i', 535156),
#    ('and', 310199),
#    ('a', 242372),
#    ('it', 148143),
#    ('that', 128064)],
#   [('to', 353244),
#    ('am', 38146),
#    ('want', 21620),
#    ('help', 21125),
#    ('will', 19994)]],
#  [3,
#   62,
#   0.89764688030922146,
#   [('i', 535156),
#    ('and', 310199),
#    ('a', 242372),
#    ('it', 148143),
#    ('that', 128064)],
#   [('the', 276612),
#    ('of', 172921),
#    ('from', 25203),
#    ('an', 16676),
#    ('which', 15861)]],
#  [3,
#   66,
#   0.65395109074377988,
#   [('i', 535156),
#    ('and', 310199),
#    ('a', 242372),
#    ('it', 148143),
#    ('that', 128064)],
#   [('more', 22922),
#    ('feel', 20604),
#    ('bit', 4893),
#    ('less', 3819),
#    ('weird', 2299)]],
#  [3,
#   67,
#   0.71349927325017337,
#   [('i', 535156),
#    ('and', 310199),
#    ('a', 242372),
#    ('it', 148143),
#    ('that', 128064)],
#   [('cant', 17788),
#    ('hard', 9150),
#    ('sometimes', 5997),
#    ('often', 4659),
#    ('forget', 3322)]],
#  [3,
#   73,
#   0.73845013876777177,
#   [('i', 535156),
#    ('and', 310199),
#    ('a', 242372),
#    ('it', 148143),
#    ('that', 128064)],
#   [('said', 7762),
#    ('told', 6746),
#    ('tell', 6024),
#    ('talk', 5551),
#    ('understand', 4477)]],
#  [3,
#   80,
#   0.68396473971019212,
#   [('i', 535156),
#    ('and', 310199),
#    ('a', 242372),
#    ('it', 148143),
#    ('that', 128064)],
#   [('very', 15221),
#    ('person', 5367),
#    ('happy', 3018),
#    ('become', 2916),
#    ('interested', 1888)]],
#  [3,
#   83,
#   0.88764570617709482,
#   [('i', 535156),
#    ('and', 310199),
#    ('a', 242372),
#    ('it', 148143),
#    ('that', 128064)],
#   [('on', 87058),
#    ('get', 45512),
#    ('out', 26215),
#    ('up', 21010),
#    ('them', 18336)]],
#  [3,
#   84,
#   0.65000294290571581,
#   [('i', 535156),
#    ('and', 310199),
#    ('a', 242372),
#    ('it', 148143),
#    ('that', 128064)],
#   [('being', 14946),
#    ('lazy', 2367),
#    ('stupid', 2120),
#    ('smart', 1140),
#    ('act', 1014)]],
#  [3,
#   99,
#   0.71844826562325026,
#   [('i', 535156),
#    ('and', 310199),
#    ('a', 242372),
#    ('it', 148143),
#    ('that', 128064)],
#   [('work', 25949),
#    ('things', 24599),
#    ('doing', 13220),
#    ('done', 11159),
#    ('etc', 6080)]],
#  [6,
#   36,
#   0.6544624291832023,
#   [('do', 61744),
#    ('make', 12200),
#    ('find', 11436),
#    ('keep', 7870),
#    ('able', 5035)],
#   [('one', 22863),
#    ('long', 8918),
#    ('days', 6881),
#    ('every', 6517),
#    ('two', 6037)]],
#  [6,
#   53,
#   0.66136792581769077,
#   [('do', 61744),
#    ('make', 12200),
#    ('find', 11436),
#    ('keep', 7870),
#    ('able', 5035)],
#   [('life', 18478),
#    ('myself', 15524),
#    ('getting', 12259),
#    ('having', 10137),
#    ('through', 9882)]],
#  [6,
#   61,
#   0.8037813458976838,
#   [('do', 61744),
#    ('make', 12200),
#    ('find', 11436),
#    ('keep', 7870),
#    ('able', 5035)],
#   [('to', 353244),
#    ('am', 38146),
#    ('want', 21620),
#    ('help', 21125),
#    ('will', 19994)]],
#  [6,
#   62,
#   0.73436286296521791,
#   [('do', 61744),
#    ('make', 12200),
#    ('find', 11436),
#    ('keep', 7870),
#    ('able', 5035)],
#   [('the', 276612),
#    ('of', 172921),
#    ('from', 25203),
#    ('an', 16676),
#    ('which', 15861)]],
#  [6,
#   83,
#   0.75233576853866158,
#   [('do', 61744),
#    ('make', 12200),
#    ('find', 11436),
#    ('keep', 7870),
#    ('able', 5035)],
#   [('on', 87058),
#    ('get', 45512),
#    ('out', 26215),
#    ('up', 21010),
#    ('them', 18336)]],
#  [6,
#   99,
#   0.71241934100372784,
#   [('do', 61744),
#    ('make', 12200),
#    ('find', 11436),
#    ('keep', 7870),
#    ('able', 5035)],
#   [('work', 25949),
#    ('things', 24599),
#    ('doing', 13220),
#    ('done', 11159),
#    ('etc', 6080)]],
#  [7,
#   11,
#   0.91229937719791421,
#   [('daily_challenge_sometimes', 97),
#    ('from_your_moderation', 96),
#    ('win_wednesday_recognizing', 92)],
#   [('effect_our', 143),
#    ('by_reacting_more', 142),
#    ('in_negativity_bias', 142),
#    ('science_behind_win_wednesday', 107),
#    ('scientists_think_our', 105)]],
#  [7,
#   17,
#   0.71813829545335039,
#   [('daily_challenge_sometimes', 97),
#    ('from_your_moderation', 96),
#    ('win_wednesday_recognizing', 92)],
#   [('for_negative_experiences', 142),
#    ('is_like_velcro', 142),
#    ('teflon_for_positive_ones', 142),
#    ('than_positive_ones', 142),
#    ('causing_us', 98)]],
#  [7,
#   30,
#   0.74940086894192726,
#   [('daily_challenge_sometimes', 97),
#    ('from_your_moderation', 96),
#    ('win_wednesday_recognizing', 92)],
#   [('win_wednesday', 634),
#    ('celebrate', 401),
#    ('wins', 293),
#    ('equally', 252),
#    ('us_have_victories', 172)]],
#  [7,
#   43,
#   0.89465075735287247,
#   [('daily_challenge_sometimes', 97),
#    ('from_your_moderation', 96),
#    ('win_wednesday_recognizing', 92)],
#   [('on_our_accomplishments', 142),
#    ('more_at_rickhanson', 117),
#    ('net_link_win_wednesday', 117)]],
#  [7,
#   45,
#   0.65300550927856138,
#   [('daily_challenge_sometimes', 97),
#    ('from_your_moderation', 96),
#    ('win_wednesday_recognizing', 92)],
#   [('one_whatever_level', 172),
#    ('win_wednesday_no_victory', 172),
#    ('each_other_your', 135),
#    ('more_normal_wrote', 100),
#    ('join_our_other_exciting', 91)]],
#  [7,
#   46,
#   0.94633141985893054,
#   [('daily_challenge_sometimes', 97),
#    ('from_your_moderation', 96),
#    ('win_wednesday_recognizing', 92)],
#   [('gather', 232),
#    ('keeping_track', 192),
#    ('from_slipping_away', 96),
#    ('stop_positive_experiences', 96),
#    ('this_slowly_changes', 96)]],
#  [7,
#   70,
#   0.89611469609861338,
#   [('daily_challenge_sometimes', 97),
#    ('from_your_moderation', 96),
#    ('win_wednesday_recognizing', 92)],
#   [('pdf', 223),
#    ('his_positive_emotions', 121),
#    ('this_information_comes', 121),
#    ('buddhas_brain_by_rick', 107),
#    ('hanson_here_is', 107)]],
#  [7,
#   71,
#   0.7566142745566915,
#   [('daily_challenge_sometimes', 97),
#    ('from_your_moderation', 96),
#    ('win_wednesday_recognizing', 92)],
#   [('views', 267),
#    ('cheer', 193),
#    ('week_win_wednesday', 153),
#    ('give_positive_support', 143),
#    ('those_posting_not', 143)]],
#  [7,
#   89,
#   0.72787110342651351,
#   [('daily_challenge_sometimes', 97),
#    ('from_your_moderation', 96),
#    ('win_wednesday_recognizing', 92)],
#   [('every_single_day', 295),
#    ('list_later', 112),
#    ('we_win', 110),
#    ('write_down_your_wins', 98),
#    ('are_rarely_good', 97)]],
#  [7,
#   96,
#   0.87771161499279082,
#   [('daily_challenge_sometimes', 97),
#    ('from_your_moderation', 96),
#    ('win_wednesday_recognizing', 92)],
#   [('curve', 156),
#    ('good_job_means', 142),
#    ('examples_from_past', 133),
#    ('been_struggling_phenomenal', 125),
#    ('no_longer_playing_catch', 100)]],
#  [7,
#   97,
#   0.87009098005381147,
#   [('daily_challenge_sometimes', 97),
#    ('from_your_moderation', 96),
#    ('win_wednesday_recognizing', 92)],
#   [('ratio', 195),
#    ('negative_interactions', 104),
#    ('playing_feild_by', 94),
#    ('negative_interactions_by_tilting', 46)]],
#  [10,
#   58,
#   0.94203482325355758,
#   [('week_daily_habit', 116),
#    ('tuesday_wednesday_thursday_friday', 114),
#    ('come_together', 95),
#    ('our_other_exciting', 75),
#    ('weekly_threads_win_wednesday', 75)],
#   [('when_potential_obstacles', 119),
#    ('small_start_reward', 116),
#    ('daily_habit_procrastinated_project', 74),
#    ('soul_feeding_what', 74),
#    ('respond_project_plan', 73)]],
#  [10,
#   69,
#   0.93671755992165462,
#   [('week_daily_habit', 116),
#    ('tuesday_wednesday_thursday_friday', 114),
#    ('come_together', 95),
#    ('our_other_exciting', 75),
#    ('weekly_threads_win_wednesday', 75)],
#   [('examples_from_previous_weeks', 127),
#    ('unload', 106),
#    ('suggest_starting_small', 87),
#    ('dishwasher_study_x', 86),
#    ('easiest_time_for', 75)]],
#  [11,
#   17,
#   0.93429240919018297,
#   [('effect_our', 143),
#    ('by_reacting_more', 142),
#    ('in_negativity_bias', 142),
#    ('science_behind_win_wednesday', 107),
#    ('scientists_think_our', 105)],
#   [('for_negative_experiences', 142),
#    ('is_like_velcro', 142),
#    ('teflon_for_positive_ones', 142),
#    ('than_positive_ones', 142),
#    ('causing_us', 98)]],
#  [11,
#   30,
#   0.90057659175440696,
#   [('effect_our', 143),
#    ('by_reacting_more', 142),
#    ('in_negativity_bias', 142),
#    ('science_behind_win_wednesday', 107),
#    ('scientists_think_our', 105)],
#   [('win_wednesday', 634),
#    ('celebrate', 401),
#    ('wins', 293),
#    ('equally', 252),
#    ('us_have_victories', 172)]],
#  [11,
#   43,
#   0.97987020370640954,
#   [('effect_our', 143),
#    ('by_reacting_more', 142),
#    ('in_negativity_bias', 142),
#    ('science_behind_win_wednesday', 107),
#    ('scientists_think_our', 105)],
#   [('on_our_accomplishments', 142),
#    ('more_at_rickhanson', 117),
#    ('net_link_win_wednesday', 117)]],
#  [11,
#   45,
#   0.67504385797254329,
#   [('effect_our', 143),
#    ('by_reacting_more', 142),
#    ('in_negativity_bias', 142),
#    ('science_behind_win_wednesday', 107),
#    ('scientists_think_our', 105)],
#   [('one_whatever_level', 172),
#    ('win_wednesday_no_victory', 172),
#    ('each_other_your', 135),
#    ('more_normal_wrote', 100),
#    ('join_our_other_exciting', 91)]],
#  [11,
#   46,
#   0.86757095159866937,
#   [('effect_our', 143),
#    ('by_reacting_more', 142),
#    ('in_negativity_bias', 142),
#    ('science_behind_win_wednesday', 107),
#    ('scientists_think_our', 105)],
#   [('gather', 232),
#    ('keeping_track', 192),
#    ('from_slipping_away', 96),
#    ('stop_positive_experiences', 96),
#    ('this_slowly_changes', 96)]],
#  [11,
#   70,
#   0.93722893263516704,
#   [('effect_our', 143),
#    ('by_reacting_more', 142),
#    ('in_negativity_bias', 142),
#    ('science_behind_win_wednesday', 107),
#    ('scientists_think_our', 105)],
#   [('pdf', 223),
#    ('his_positive_emotions', 121),
#    ('this_information_comes', 121),
#    ('buddhas_brain_by_rick', 107),
#    ('hanson_here_is', 107)]],
#  [11,
#   71,
#   0.91784239228332498,
#   [('effect_our', 143),
#    ('by_reacting_more', 142),
#    ('in_negativity_bias', 142),
#    ('science_behind_win_wednesday', 107),
#    ('scientists_think_our', 105)],
#   [('views', 267),
#    ('cheer', 193),
#    ('week_win_wednesday', 153),
#    ('give_positive_support', 143),
#    ('those_posting_not', 143)]],
#  [11,
#   89,
#   0.69289057534327358,
#   [('effect_our', 143),
#    ('by_reacting_more', 142),
#    ('in_negativity_bias', 142),
#    ('science_behind_win_wednesday', 107),
#    ('scientists_think_our', 105)],
#   [('every_single_day', 295),
#    ('list_later', 112),
#    ('we_win', 110),
#    ('write_down_your_wins', 98),
#    ('are_rarely_good', 97)]],
#  [11,
#   96,
#   0.93358535276273491,
#   [('effect_our', 143),
#    ('by_reacting_more', 142),
#    ('in_negativity_bias', 142),
#    ('science_behind_win_wednesday', 107),
#    ('scientists_think_our', 105)],
#   [('curve', 156),
#    ('good_job_means', 142),
#    ('examples_from_past', 133),
#    ('been_struggling_phenomenal', 125),
#    ('no_longer_playing_catch', 100)]],
#  [11,
#   97,
#   0.95846489756292164,
#   [('effect_our', 143),
#    ('by_reacting_more', 142),
#    ('in_negativity_bias', 142),
#    ('science_behind_win_wednesday', 107),
#    ('scientists_think_our', 105)],
#   [('ratio', 195),
#    ('negative_interactions', 104),
#    ('playing_feild_by', 94),
#    ('negative_interactions_by_tilting', 46)]],
#  [16,
#   31,
#   0.71261244461280615,
#   [('been', 24612),
#    ('since', 11348),
#    ('ive_been', 10559),
#    ('years', 8671),
#    ('year', 5689)],
#   [('my', 203658),
#    ('was', 80310),
#    ('had', 32794),
#    ('ive', 22719),
#    ('after', 19616)]],
#  [17,
#   30,
#   0.91661610092552104,
#   [('for_negative_experiences', 142),
#    ('is_like_velcro', 142),
#    ('teflon_for_positive_ones', 142),
#    ('than_positive_ones', 142),
#    ('causing_us', 98)],
#   [('win_wednesday', 634),
#    ('celebrate', 401),
#    ('wins', 293),
#    ('equally', 252),
#    ('us_have_victories', 172)]],
#  [17,
#   43,
#   0.91754556223133998,
#   [('for_negative_experiences', 142),
#    ('is_like_velcro', 142),
#    ('teflon_for_positive_ones', 142),
#    ('than_positive_ones', 142),
#    ('causing_us', 98)],
#   [('on_our_accomplishments', 142),
#    ('more_at_rickhanson', 117),
#    ('net_link_win_wednesday', 117)]],
#  [17,
#   46,
#   0.68144305355929324,
#   [('for_negative_experiences', 142),
#    ('is_like_velcro', 142),
#    ('teflon_for_positive_ones', 142),
#    ('than_positive_ones', 142),
#    ('causing_us', 98)],
#   [('gather', 232),
#    ('keeping_track', 192),
#    ('from_slipping_away', 96),
#    ('stop_positive_experiences', 96),
#    ('this_slowly_changes', 96)]],
#  [17,
#   70,
#   0.83954070535219938,
#   [('for_negative_experiences', 142),
#    ('is_like_velcro', 142),
#    ('teflon_for_positive_ones', 142),
#    ('than_positive_ones', 142),
#    ('causing_us', 98)],
#   [('pdf', 223),
#    ('his_positive_emotions', 121),
#    ('this_information_comes', 121),
#    ('buddhas_brain_by_rick', 107),
#    ('hanson_here_is', 107)]],
#  [17,
#   71,
#   0.93429497906230419,
#   [('for_negative_experiences', 142),
#    ('is_like_velcro', 142),
#    ('teflon_for_positive_ones', 142),
#    ('than_positive_ones', 142),
#    ('causing_us', 98)],
#   [('views', 267),
#    ('cheer', 193),
#    ('week_win_wednesday', 153),
#    ('give_positive_support', 143),
#    ('those_posting_not', 143)]],
#  [17,
#   79,
#   0.69218159188667361,
#   [('for_negative_experiences', 142),
#    ('is_like_velcro', 142),
#    ('teflon_for_positive_ones', 142),
#    ('than_positive_ones', 142),
#    ('causing_us', 98)],
#   [('wiring', 72),
#    ('bit_longer', 68),
#    ('positive_events_in', 47),
#    ('are_slowly_changing', 46),
#    ('implicit_memory_deep_down', 46)]],
#  [17,
#   96,
#   0.86448310487774682,
#   [('for_negative_experiences', 142),
#    ('is_like_velcro', 142),
#    ('teflon_for_positive_ones', 142),
#    ('than_positive_ones', 142),
#    ('causing_us', 98)],
#   [('curve', 156),
#    ('good_job_means', 142),
#    ('examples_from_past', 133),
#    ('been_struggling_phenomenal', 125),
#    ('no_longer_playing_catch', 100)]],
#  [17,
#   97,
#   0.90761484882626564,
#   [('for_negative_experiences', 142),
#    ('is_like_velcro', 142),
#    ('teflon_for_positive_ones', 142),
#    ('than_positive_ones', 142),
#    ('causing_us', 98)],
#   [('ratio', 195),
#    ('negative_interactions', 104),
#    ('playing_feild_by', 94),
#    ('negative_interactions_by_tilting', 46)]],
#  [18,
#   31,
#   0.68925721505421145,
#   [('some', 24841),
#    ('other', 13101),
#    ('lot', 12478),
#    ('these', 9147),
#    ('most', 8148)],
#   [('my', 203658),
#    ('was', 80310),
#    ('had', 32794),
#    ('ive', 22719),
#    ('after', 19616)]],
#  [18,
#   36,
#   0.67153988566489831,
#   [('some', 24841),
#    ('other', 13101),
#    ('lot', 12478),
#    ('these', 9147),
#    ('most', 8148)],
#   [('one', 22863),
#    ('long', 8918),
#    ('days', 6881),
#    ('every', 6517),
#    ('two', 6037)]],
#  [18,
#   61,
#   0.75361892221318461,
#   [('some', 24841),
#    ('other', 13101),
#    ('lot', 12478),
#    ('these', 9147),
#    ('most', 8148)],
#   [('to', 353244),
#    ('am', 38146),
#    ('want', 21620),
#    ('help', 21125),
#    ('will', 19994)]],
#  [18,
#   62,
#   0.80421907439347085,
#   [('some', 24841),
#    ('other', 13101),
#    ('lot', 12478),
#    ('these', 9147),
#    ('most', 8148)],
#   [('the', 276612),
#    ('of', 172921),
#    ('from', 25203),
#    ('an', 16676),
#    ('which', 15861)]],
#  [18,
#   83,
#   0.71196465437055356,
#   [('some', 24841),
#    ('other', 13101),
#    ('lot', 12478),
#    ('these', 9147),
#    ('most', 8148)],
#   [('on', 87058),
#    ('get', 45512),
#    ('out', 26215),
#    ('up', 21010),
#    ('them', 18336)]],
#  [30,
#   43,
#   0.88731962285627286,
#   [('win_wednesday', 634),
#    ('celebrate', 401),
#    ('wins', 293),
#    ('equally', 252),
#    ('us_have_victories', 172)],
#   [('on_our_accomplishments', 142),
#    ('more_at_rickhanson', 117),
#    ('net_link_win_wednesday', 117)]],
#  [30,
#   45,
#   0.70780311166653198,
#   [('win_wednesday', 634),
#    ('celebrate', 401),
#    ('wins', 293),
#    ('equally', 252),
#    ('us_have_victories', 172)],
#   [('one_whatever_level', 172),
#    ('win_wednesday_no_victory', 172),
#    ('each_other_your', 135),
#    ('more_normal_wrote', 100),
#    ('join_our_other_exciting', 91)]],
#  [30,
#   46,
#   0.71195056972420467,
#   [('win_wednesday', 634),
#    ('celebrate', 401),
#    ('wins', 293),
#    ('equally', 252),
#    ('us_have_victories', 172)],
#   [('gather', 232),
#    ('keeping_track', 192),
#    ('from_slipping_away', 96),
#    ('stop_positive_experiences', 96),
#    ('this_slowly_changes', 96)]],
#  [30,
#   70,
#   0.82348722966514676,
#   [('win_wednesday', 634),
#    ('celebrate', 401),
#    ('wins', 293),
#    ('equally', 252),
#    ('us_have_victories', 172)],
#   [('pdf', 223),
#    ('his_positive_emotions', 121),
#    ('this_information_comes', 121),
#    ('buddhas_brain_by_rick', 107),
#    ('hanson_here_is', 107)]],
#  [30,
#   71,
#   0.94846936808965476,
#   [('win_wednesday', 634),
#    ('celebrate', 401),
#    ('wins', 293),
#    ('equally', 252),
#    ('us_have_victories', 172)],
#   [('views', 267),
#    ('cheer', 193),
#    ('week_win_wednesday', 153),
#    ('give_positive_support', 143),
#    ('those_posting_not', 143)]],
#  [30,
#   96,
#   0.89058859681401481,
#   [('win_wednesday', 634),
#    ('celebrate', 401),
#    ('wins', 293),
#    ('equally', 252),
#    ('us_have_victories', 172)],
#   [('curve', 156),
#    ('good_job_means', 142),
#    ('examples_from_past', 133),
#    ('been_struggling_phenomenal', 125),
#    ('no_longer_playing_catch', 100)]],
#  [30,
#   97,
#   0.87454511456022388,
#   [('win_wednesday', 634),
#    ('celebrate', 401),
#    ('wins', 293),
#    ('equally', 252),
#    ('us_have_victories', 172)],
#   [('ratio', 195),
#    ('negative_interactions', 104),
#    ('playing_feild_by', 94),
#    ('negative_interactions_by_tilting', 46)]],
#  [31,
#   36,
#   0.72661378455398673,
#   [('my', 203658),
#    ('was', 80310),
#    ('had', 32794),
#    ('ive', 22719),
#    ('after', 19616)],
#   [('one', 22863),
#    ('long', 8918),
#    ('days', 6881),
#    ('every', 6517),
#    ('two', 6037)]],
#  [31,
#   53,
#   0.73948200033842293,
#   [('my', 203658),
#    ('was', 80310),
#    ('had', 32794),
#    ('ive', 22719),
#    ('after', 19616)],
#   [('life', 18478),
#    ('myself', 15524),
#    ('getting', 12259),
#    ('having', 10137),
#    ('through', 9882)]],
#  [31,
#   61,
#   0.81091013104748877,
#   [('my', 203658),
#    ('was', 80310),
#    ('had', 32794),
#    ('ive', 22719),
#    ('after', 19616)],
#   [('to', 353244),
#    ('am', 38146),
#    ('want', 21620),
#    ('help', 21125),
#    ('will', 19994)]],
#  [31,
#   62,
#   0.80622431283692031,
#   [('my', 203658),
#    ('was', 80310),
#    ('had', 32794),
#    ('ive', 22719),
#    ('after', 19616)],
#   [('the', 276612),
#    ('of', 172921),
#    ('from', 25203),
#    ('an', 16676),
#    ('which', 15861)]],
#  [31,
#   73,
#   0.68426564839405235,
#   [('my', 203658),
#    ('was', 80310),
#    ('had', 32794),
#    ('ive', 22719),
#    ('after', 19616)],
#   [('said', 7762),
#    ('told', 6746),
#    ('tell', 6024),
#    ('talk', 5551),
#    ('understand', 4477)]],
#  [31,
#   83,
#   0.79601884018858859,
#   [('my', 203658),
#    ('was', 80310),
#    ('had', 32794),
#    ('ive', 22719),
#    ('after', 19616)],
#   [('on', 87058),
#    ('get', 45512),
#    ('out', 26215),
#    ('up', 21010),
#    ('them', 18336)]],
#  [36,
#   61,
#   0.75556139323227356,
#   [('one', 22863),
#    ('long', 8918),
#    ('days', 6881),
#    ('every', 6517),
#    ('two', 6037)],
#   [('to', 353244),
#    ('am', 38146),
#    ('want', 21620),
#    ('help', 21125),
#    ('will', 19994)]],
#  [36,
#   62,
#   0.80080533563058043,
#   [('one', 22863),
#    ('long', 8918),
#    ('days', 6881),
#    ('every', 6517),
#    ('two', 6037)],
#   [('the', 276612),
#    ('of', 172921),
#    ('from', 25203),
#    ('an', 16676),
#    ('which', 15861)]],
#  [36,
#   83,
#   0.76214303453235055,
#   [('one', 22863),
#    ('long', 8918),
#    ('days', 6881),
#    ('every', 6517),
#    ('two', 6037)],
#   [('on', 87058),
#    ('get', 45512),
#    ('out', 26215),
#    ('up', 21010),
#    ('them', 18336)]],
#  [37,
#   45,
#   0.78019325769351244,
#   [('whole_point', 189),
#    ('how_you_won', 175),
#    ('cause_for_celebration', 174),
#    ('kick_start_sunday', 170),
#    ('please_dont_discount', 143)],
#   [('one_whatever_level', 172),
#    ('win_wednesday_no_victory', 172),
#    ('each_other_your', 135),
#    ('more_normal_wrote', 100),
#    ('join_our_other_exciting', 91)]],
#  [37,
#   58,
#   0.76634535439823015,
#   [('whole_point', 189),
#    ('how_you_won', 175),
#    ('cause_for_celebration', 174),
#    ('kick_start_sunday', 170),
#    ('please_dont_discount', 143)],
#   [('when_potential_obstacles', 119),
#    ('small_start_reward', 116),
#    ('daily_habit_procrastinated_project', 74),
#    ('soul_feeding_what', 74),
#    ('respond_project_plan', 73)]],
#  [37,
#   77,
#   0.80601297527063454,
#   [('whole_point', 189),
#    ('how_you_won', 175),
#    ('cause_for_celebration', 174),
#    ('kick_start_sunday', 170),
#    ('please_dont_discount', 143)],
#   [('pick_up_trash', 50),
#    ('handle_pick', 49),
#    ('say_clean_room', 49),
#    ('saying_clean', 49),
#    ('your_entire_house', 49)]],
#  [37,
#   89,
#   0.69891310163188836,
#   [('whole_point', 189),
#    ('how_you_won', 175),
#    ('cause_for_celebration', 174),
#    ('kick_start_sunday', 170),
#    ('please_dont_discount', 143)],
#   [('every_single_day', 295),
#    ('list_later', 112),
#    ('we_win', 110),
#    ('write_down_your_wins', 98),
#    ('are_rarely_good', 97)]],
#  [37,
#   93,
#   0.78751133036485799,
#   [('whole_point', 189),
#    ('how_you_won', 175),
#    ('cause_for_celebration', 174),
#    ('kick_start_sunday', 170),
#    ('please_dont_discount', 143)],
#   [('creates_momentum_trust', 48),
#    ('in_yourself_confidence', 48),
#    ('for_win_wedenesday', 38),
#    ('flaunt_your_successes_by', 37),
#    ('prioritize_your_list', 36)]],
#  [37,
#   94,
#   0.8082576106317062,
#   [('whole_point', 189),
#    ('how_you_won', 175),
#    ('cause_for_celebration', 174),
#    ('kick_start_sunday', 170),
#    ('please_dont_discount', 143)],
#   [('are_flaky_start', 49),
#    ('by_computer_google', 49),
#    ('calendar_agenda_write', 49),
#    ('down_elsewhere_sticky_note', 49),
#    ('on_small_successes', 49)]],
#  [43,
#   45,
#   0.66737344133753262,
#   [('on_our_accomplishments', 142),
#    ('more_at_rickhanson', 117),
#    ('net_link_win_wednesday', 117)],
#   [('one_whatever_level', 172),
#    ('win_wednesday_no_victory', 172),
#    ('each_other_your', 135),
#    ('more_normal_wrote', 100),
#    ('join_our_other_exciting', 91)]],
#  [43,
#   46,
#   0.8503585318376391,
#   [('on_our_accomplishments', 142),
#    ('more_at_rickhanson', 117),
#    ('net_link_win_wednesday', 117)],
#   [('gather', 232),
#    ('keeping_track', 192),
#    ('from_slipping_away', 96),
#    ('stop_positive_experiences', 96),
#    ('this_slowly_changes', 96)]],
#  [43,
#   70,
#   0.95889678216446872,
#   [('on_our_accomplishments', 142),
#    ('more_at_rickhanson', 117),
#    ('net_link_win_wednesday', 117)],
#   [('pdf', 223),
#    ('his_positive_emotions', 121),
#    ('this_information_comes', 121),
#    ('buddhas_brain_by_rick', 107),
#    ('hanson_here_is', 107)]],
#  [43,
#   71,
#   0.89894204124888921,
#   [('on_our_accomplishments', 142),
#    ('more_at_rickhanson', 117),
#    ('net_link_win_wednesday', 117)],
#   [('views', 267),
#    ('cheer', 193),
#    ('week_win_wednesday', 153),
#    ('give_positive_support', 143),
#    ('those_posting_not', 143)]],
#  [43,
#   89,
#   0.69532721057837854,
#   [('on_our_accomplishments', 142),
#    ('more_at_rickhanson', 117),
#    ('net_link_win_wednesday', 117)],
#   [('every_single_day', 295),
#    ('list_later', 112),
#    ('we_win', 110),
#    ('write_down_your_wins', 98),
#    ('are_rarely_good', 97)]],
#  [43,
#   96,
#   0.93686533716565257,
#   [('on_our_accomplishments', 142),
#    ('more_at_rickhanson', 117),
#    ('net_link_win_wednesday', 117)],
#   [('curve', 156),
#    ('good_job_means', 142),
#    ('examples_from_past', 133),
#    ('been_struggling_phenomenal', 125),
#    ('no_longer_playing_catch', 100)]],
#  [43,
#   97,
#   0.94049133832676846,
#   [('on_our_accomplishments', 142),
#    ('more_at_rickhanson', 117),
#    ('net_link_win_wednesday', 117)],
#   [('ratio', 195),
#    ('negative_interactions', 104),
#    ('playing_feild_by', 94),
#    ('negative_interactions_by_tilting', 46)]],
#  [45,
#   71,
#   0.65314831047110566,
#   [('one_whatever_level', 172),
#    ('win_wednesday_no_victory', 172),
#    ('each_other_your', 135),
#    ('more_normal_wrote', 100),
#    ('join_our_other_exciting', 91)],
#   [('views', 267),
#    ('cheer', 193),
#    ('week_win_wednesday', 153),
#    ('give_positive_support', 143),
#    ('those_posting_not', 143)]],
#  [45,
#   77,
#   0.6791466225624323,
#   [('one_whatever_level', 172),
#    ('win_wednesday_no_victory', 172),
#    ('each_other_your', 135),
#    ('more_normal_wrote', 100),
#    ('join_our_other_exciting', 91)],
#   [('pick_up_trash', 50),
#    ('handle_pick', 49),
#    ('say_clean_room', 49),
#    ('saying_clean', 49),
#    ('your_entire_house', 49)]],
#  [45,
#   89,
#   0.93844307099367619,
#   [('one_whatever_level', 172),
#    ('win_wednesday_no_victory', 172),
#    ('each_other_your', 135),
#    ('more_normal_wrote', 100),
#    ('join_our_other_exciting', 91)],
#   [('every_single_day', 295),
#    ('list_later', 112),
#    ('we_win', 110),
#    ('write_down_your_wins', 98),
#    ('are_rarely_good', 97)]],
#  [45,
#   93,
#   0.6789982641587422,
#   [('one_whatever_level', 172),
#    ('win_wednesday_no_victory', 172),
#    ('each_other_your', 135),
#    ('more_normal_wrote', 100),
#    ('join_our_other_exciting', 91)],
#   [('creates_momentum_trust', 48),
#    ('in_yourself_confidence', 48),
#    ('for_win_wedenesday', 38),
#    ('flaunt_your_successes_by', 37),
#    ('prioritize_your_list', 36)]],
#  [45,
#   94,
#   0.67684770576784781,
#   [('one_whatever_level', 172),
#    ('win_wednesday_no_victory', 172),
#    ('each_other_your', 135),
#    ('more_normal_wrote', 100),
#    ('join_our_other_exciting', 91)],
#   [('are_flaky_start', 49),
#    ('by_computer_google', 49),
#    ('calendar_agenda_write', 49),
#    ('down_elsewhere_sticky_note', 49),
#    ('on_small_successes', 49)]],
#  [45,
#   96,
#   0.6897558896103877,
#   [('one_whatever_level', 172),
#    ('win_wednesday_no_victory', 172),
#    ('each_other_your', 135),
#    ('more_normal_wrote', 100),
#    ('join_our_other_exciting', 91)],
#   [('curve', 156),
#    ('good_job_means', 142),
#    ('examples_from_past', 133),
#    ('been_struggling_phenomenal', 125),
#    ('no_longer_playing_catch', 100)]],
#  [45,
#   97,
#   0.6521416065926311,
#   [('one_whatever_level', 172),
#    ('win_wednesday_no_victory', 172),
#    ('each_other_your', 135),
#    ('more_normal_wrote', 100),
#    ('join_our_other_exciting', 91)],
#   [('ratio', 195),
#    ('negative_interactions', 104),
#    ('playing_feild_by', 94),
#    ('negative_interactions_by_tilting', 46)]],
#  [46,
#   70,
#   0.85249547681896476,
#   [('gather', 232),
#    ('keeping_track', 192),
#    ('from_slipping_away', 96),
#    ('stop_positive_experiences', 96),
#    ('this_slowly_changes', 96)],
#   [('pdf', 223),
#    ('his_positive_emotions', 121),
#    ('this_information_comes', 121),
#    ('buddhas_brain_by_rick', 107),
#    ('hanson_here_is', 107)]],
#  [46,
#   71,
#   0.72244263832718725,
#   [('gather', 232),
#    ('keeping_track', 192),
#    ('from_slipping_away', 96),
#    ('stop_positive_experiences', 96),
#    ('this_slowly_changes', 96)],
#   [('views', 267),
#    ('cheer', 193),
#    ('week_win_wednesday', 153),
#    ('give_positive_support', 143),
#    ('those_posting_not', 143)]],
#  [46,
#   89,
#   0.69106604461632415,
#   [('gather', 232),
#    ('keeping_track', 192),
#    ('from_slipping_away', 96),
#    ('stop_positive_experiences', 96),
#    ('this_slowly_changes', 96)],
#   [('every_single_day', 295),
#    ('list_later', 112),
#    ('we_win', 110),
#    ('write_down_your_wins', 98),
#    ('are_rarely_good', 97)]],
#  [46,
#   96,
#   0.83163609762511181,
#   [('gather', 232),
#    ('keeping_track', 192),
#    ('from_slipping_away', 96),
#    ('stop_positive_experiences', 96),
#    ('this_slowly_changes', 96)],
#   [('curve', 156),
#    ('good_job_means', 142),
#    ('examples_from_past', 133),
#    ('been_struggling_phenomenal', 125),
#    ('no_longer_playing_catch', 100)]],
#  [46,
#   97,
#   0.82908441909943664,
#   [('gather', 232),
#    ('keeping_track', 192),
#    ('from_slipping_away', 96),
#    ('stop_positive_experiences', 96),
#    ('this_slowly_changes', 96)],
#   [('ratio', 195),
#    ('negative_interactions', 104),
#    ('playing_feild_by', 94),
#    ('negative_interactions_by_tilting', 46)]],
#  [53,
#   61,
#   0.75527937599988326,
#   [('life', 18478),
#    ('myself', 15524),
#    ('getting', 12259),
#    ('having', 10137),
#    ('through', 9882)],
#   [('to', 353244),
#    ('am', 38146),
#    ('want', 21620),
#    ('help', 21125),
#    ('will', 19994)]],
#  [53,
#   62,
#   0.71727250764253458,
#   [('life', 18478),
#    ('myself', 15524),
#    ('getting', 12259),
#    ('having', 10137),
#    ('through', 9882)],
#   [('the', 276612),
#    ('of', 172921),
#    ('from', 25203),
#    ('an', 16676),
#    ('which', 15861)]],
#  [53,
#   83,
#   0.72706524408805917,
#   [('life', 18478),
#    ('myself', 15524),
#    ('getting', 12259),
#    ('having', 10137),
#    ('through', 9882)],
#   [('on', 87058),
#    ('get', 45512),
#    ('out', 26215),
#    ('up', 21010),
#    ('them', 18336)]],
#  [57,
#   62,
#   0.67614482235076312,
#   [('are', 32610),
#    ('people', 21619),
#    ('we', 14409),
#    ('own', 4253),
#    ('us', 4121)],
#   [('the', 276612),
#    ('of', 172921),
#    ('from', 25203),
#    ('an', 16676),
#    ('which', 15861)]],
#  [58,
#   69,
#   0.86077860566965925,
#   [('when_potential_obstacles', 119),
#    ('small_start_reward', 116),
#    ('daily_habit_procrastinated_project', 74),
#    ('soul_feeding_what', 74),
#    ('respond_project_plan', 73)],
#   [('examples_from_previous_weeks', 127),
#    ('unload', 106),
#    ('suggest_starting_small', 87),
#    ('dishwasher_study_x', 86),
#    ('easiest_time_for', 75)]],
#  [58,
#   77,
#   0.6562121365349004,
#   [('when_potential_obstacles', 119),
#    ('small_start_reward', 116),
#    ('daily_habit_procrastinated_project', 74),
#    ('soul_feeding_what', 74),
#    ('respond_project_plan', 73)],
#   [('pick_up_trash', 50),
#    ('handle_pick', 49),
#    ('say_clean_room', 49),
#    ('saying_clean', 49),
#    ('your_entire_house', 49)]],
#  [58,
#   94,
#   0.6565382910902523,
#   [('when_potential_obstacles', 119),
#    ('small_start_reward', 116),
#    ('daily_habit_procrastinated_project', 74),
#    ('soul_feeding_what', 74),
#    ('respond_project_plan', 73)],
#   [('are_flaky_start', 49),
#    ('by_computer_google', 49),
#    ('calendar_agenda_write', 49),
#    ('down_elsewhere_sticky_note', 49),
#    ('on_small_successes', 49)]],
#  [59,
#   62,
#   0.68208615169418407,
#   [('may', 5892),
#    ('part', 4089),
#    ('issue', 2424),
#    ('positive', 2022),
#    ('disorder', 1792)],
#   [('the', 276612),
#    ('of', 172921),
#    ('from', 25203),
#    ('an', 16676),
#    ('which', 15861)]],
#  [61,
#   62,
#   0.86062348066265293,
#   [('to', 353244),
#    ('am', 38146),
#    ('want', 21620),
#    ('help', 21125),
#    ('will', 19994)],
#   [('the', 276612),
#    ('of', 172921),
#    ('from', 25203),
#    ('an', 16676),
#    ('which', 15861)]],
#  [61,
#   67,
#   0.66086872086780946,
#   [('to', 353244),
#    ('am', 38146),
#    ('want', 21620),
#    ('help', 21125),
#    ('will', 19994)],
#   [('cant', 17788),
#    ('hard', 9150),
#    ('sometimes', 5997),
#    ('often', 4659),
#    ('forget', 3322)]],
#  [61,
#   73,
#   0.71207379367064016,
#   [('to', 353244),
#    ('am', 38146),
#    ('want', 21620),
#    ('help', 21125),
#    ('will', 19994)],
#   [('said', 7762),
#    ('told', 6746),
#    ('tell', 6024),
#    ('talk', 5551),
#    ('understand', 4477)]],
#  [61,
#   83,
#   0.86423440093792392,
#   [('to', 353244),
#    ('am', 38146),
#    ('want', 21620),
#    ('help', 21125),
#    ('will', 19994)],
#   [('on', 87058),
#    ('get', 45512),
#    ('out', 26215),
#    ('up', 21010),
#    ('them', 18336)]],
#  [61,
#   99,
#   0.70256360045846777,
#   [('to', 353244),
#    ('am', 38146),
#    ('want', 21620),
#    ('help', 21125),
#    ('will', 19994)],
#   [('work', 25949),
#    ('things', 24599),
#    ('doing', 13220),
#    ('done', 11159),
#    ('etc', 6080)]],
#  [62,
#   73,
#   0.6667330396622293,
#   [('the', 276612),
#    ('of', 172921),
#    ('from', 25203),
#    ('an', 16676),
#    ('which', 15861)],
#   [('said', 7762),
#    ('told', 6746),
#    ('tell', 6024),
#    ('talk', 5551),
#    ('understand', 4477)]],
#  [62,
#   83,
#   0.82496443430594457,
#   [('the', 276612),
#    ('of', 172921),
#    ('from', 25203),
#    ('an', 16676),
#    ('which', 15861)],
#   [('on', 87058),
#    ('get', 45512),
#    ('out', 26215),
#    ('up', 21010),
#    ('them', 18336)]],
#  [62,
#   99,
#   0.66296368112798632,
#   [('the', 276612),
#    ('of', 172921),
#    ('from', 25203),
#    ('an', 16676),
#    ('which', 15861)],
#   [('work', 25949),
#    ('things', 24599),
#    ('doing', 13220),
#    ('done', 11159),
#    ('etc', 6080)]],
#  [67,
#   83,
#   0.65305317668480156,
#   [('cant', 17788),
#    ('hard', 9150),
#    ('sometimes', 5997),
#    ('often', 4659),
#    ('forget', 3322)],
#   [('on', 87058),
#    ('get', 45512),
#    ('out', 26215),
#    ('up', 21010),
#    ('them', 18336)]],
#  [70,
#   71,
#   0.83637488615968758,
#   [('pdf', 223),
#    ('his_positive_emotions', 121),
#    ('this_information_comes', 121),
#    ('buddhas_brain_by_rick', 107),
#    ('hanson_here_is', 107)],
#   [('views', 267),
#    ('cheer', 193),
#    ('week_win_wednesday', 153),
#    ('give_positive_support', 143),
#    ('those_posting_not', 143)]],
#  [70,
#   89,
#   0.68941357502787637,
#   [('pdf', 223),
#    ('his_positive_emotions', 121),
#    ('this_information_comes', 121),
#    ('buddhas_brain_by_rick', 107),
#    ('hanson_here_is', 107)],
#   [('every_single_day', 295),
#    ('list_later', 112),
#    ('we_win', 110),
#    ('write_down_your_wins', 98),
#    ('are_rarely_good', 97)]],
#  [70,
#   96,
#   0.90206587069825206,
#   [('pdf', 223),
#    ('his_positive_emotions', 121),
#    ('this_information_comes', 121),
#    ('buddhas_brain_by_rick', 107),
#    ('hanson_here_is', 107)],
#   [('curve', 156),
#    ('good_job_means', 142),
#    ('examples_from_past', 133),
#    ('been_struggling_phenomenal', 125),
#    ('no_longer_playing_catch', 100)]],
#  [70,
#   97,
#   0.89594141170191921,
#   [('pdf', 223),
#    ('his_positive_emotions', 121),
#    ('this_information_comes', 121),
#    ('buddhas_brain_by_rick', 107),
#    ('hanson_here_is', 107)],
#   [('ratio', 195),
#    ('negative_interactions', 104),
#    ('playing_feild_by', 94),
#    ('negative_interactions_by_tilting', 46)]],
#  [71,
#   96,
#   0.90699359710445793,
#   [('views', 267),
#    ('cheer', 193),
#    ('week_win_wednesday', 153),
#    ('give_positive_support', 143),
#    ('those_posting_not', 143)],
#   [('curve', 156),
#    ('good_job_means', 142),
#    ('examples_from_past', 133),
#    ('been_struggling_phenomenal', 125),
#    ('no_longer_playing_catch', 100)]],
#  [71,
#   97,
#   0.89066023024497587,
#   [('views', 267),
#    ('cheer', 193),
#    ('week_win_wednesday', 153),
#    ('give_positive_support', 143),
#    ('those_posting_not', 143)],
#   [('ratio', 195),
#    ('negative_interactions', 104),
#    ('playing_feild_by', 94),
#    ('negative_interactions_by_tilting', 46)]],
#  [77,
#   93,
#   0.95972963562975266,
#   [('pick_up_trash', 50),
#    ('handle_pick', 49),
#    ('say_clean_room', 49),
#    ('saying_clean', 49),
#    ('your_entire_house', 49)],
#   [('creates_momentum_trust', 48),
#    ('in_yourself_confidence', 48),
#    ('for_win_wedenesday', 38),
#    ('flaunt_your_successes_by', 37),
#    ('prioritize_your_list', 36)]],
#  [77,
#   94,
#   0.99843763372393191,
#   [('pick_up_trash', 50),
#    ('handle_pick', 49),
#    ('say_clean_room', 49),
#    ('saying_clean', 49),
#    ('your_entire_house', 49)],
#   [('are_flaky_start', 49),
#    ('by_computer_google', 49),
#    ('calendar_agenda_write', 49),
#    ('down_elsewhere_sticky_note', 49),
#    ('on_small_successes', 49)]],
#  [83,
#   99,
#   0.717215698636122,
#   [('on', 87058),
#    ('get', 45512),
#    ('out', 26215),
#    ('up', 21010),
#    ('them', 18336)],
#   [('work', 25949),
#    ('things', 24599),
#    ('doing', 13220),
#    ('done', 11159),
#    ('etc', 6080)]],
#  [89,
#   96,
#   0.67872342576829303,
#   [('every_single_day', 295),
#    ('list_later', 112),
#    ('we_win', 110),
#    ('write_down_your_wins', 98),
#    ('are_rarely_good', 97)],
#   [('curve', 156),
#    ('good_job_means', 142),
#    ('examples_from_past', 133),
#    ('been_struggling_phenomenal', 125),
#    ('no_longer_playing_catch', 100)]],
#  [89,
#   97,
#   0.66239781282577803,
#   [('every_single_day', 295),
#    ('list_later', 112),
#    ('we_win', 110),
#    ('write_down_your_wins', 98),
#    ('are_rarely_good', 97)],
#   [('ratio', 195),
#    ('negative_interactions', 104),
#    ('playing_feild_by', 94),
#    ('negative_interactions_by_tilting', 46)]],
#  [93,
#   94,
#   0.94824789088812012,
#   [('creates_momentum_trust', 48),
#    ('in_yourself_confidence', 48),
#    ('for_win_wedenesday', 38),
#    ('flaunt_your_successes_by', 37),
#    ('prioritize_your_list', 36)],
#   [('are_flaky_start', 49),
#    ('by_computer_google', 49),
#    ('calendar_agenda_write', 49),
#    ('down_elsewhere_sticky_note', 49),
#    ('on_small_successes', 49)]],
#  [96,
#   97,
#   0.90207899989167506,
#   [('curve', 156),
#    ('good_job_means', 142),
#    ('examples_from_past', 133),
#    ('been_struggling_phenomenal', 125),
#    ('no_longer_playing_catch', 100)],
#   [('ratio', 195),
#    ('negative_interactions', 104),
#    ('playing_feild_by', 94),
#    ('negative_interactions_by_tilting', 46)]]]

# %%
import os
directories = ['correlation-analysis']
for dirname in directories:
    if not os.path.exists(dirname):
        os.makedirs(dirname)

# %%
import csv
heading = ["cluster 1 number", "cluster 2 number", "correlation values","cluster 1","cluster 2"]
with open("correlation-analysis/"+model_name+"-correlations.csv","w") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(heading)
    [writer.writerow(r) for r in correlations_list]
